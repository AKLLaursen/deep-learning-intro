# %% [markdown]
# # Examples of Style Transfer
#
# This notebooks contains various examples of Style transfer in the style of Johnson et. al. *Perceptual losses for real-time style transfer.*

# %% [markdown]
# ## Setup
#
# Load functions, libraries and set paths.

# %%
# Plots displayed inline in notebook
# %matplotlib inline

# Make help libraries available
import sys

sys.path.append('D:/anlaursen/libraries')

# Set visible devices, so as to just use a single GPU.
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import bcolz
import tensorflow as tf

from styletransfer.styletransfer import StyleTransfer

#tf.GPUOptions(per_process_gpu_memory_fraction = 0.333)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Load training data can convert to numpy array

# %%
imagenet = bcolz.open('data/trn_resized_288.bc')[:]

# %% [markdown]
# ## Van Gogh
#
# Attempt using a Van Gogh self portrait

# %% [markdown]
# Create style transfer model

# %%
van_gogh_style = StyleTransfer(style_path = 'data/styles/van-gogh-self-portrait.jpg')

# %% [markdown]
# Display style image

# %%
van_gogh_style.plot_style()

# %% [markdown]
# Compile model

# %%
van_gogh_style.compile()

# %% [markdown]
# Train model

# %%
van_gogh_style.fit(imagenet,
                   batch_size = 8,
                   epochs = 2,
                   learning_rate = 1e-3)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %% [markdown]
# Lower learning rate and run another epoch

# %%
van_gogh_style.fit(imagenet,
                   batch_size = 8,
                   epochs = 1,
                   learning_rate = 1e-4)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %% [markdown]
# Save weights

# %%
van_gogh_style.m_style.save_weights('results/van-gogh-self-portrait.h5')

# %% [markdown]
# Plot test image.

# %%
van_gogh_style.plot_image('test/akll-bw-big.jpg')

# %%
van_gogh_style.plot_image('test/akll-color-big.jpg')

# %% [markdown]
# Initiate style transfer model

# %%
van_gogh_style.get_top()

# %% [markdown]
# Save weights

# %%
van_gogh_style.top_model.save_weights('results/van-gogh-self-portrait-top.h5')

# %% [markdown]
# Make prediction

# %%
van_gogh_akll_big = van_gogh_style.predict('test/akll-bw-big.jpg')

# %%
van_gogh_akll_big = van_gogh_style.predict('test/akll-color-big.jpg')

# %% [markdown]
# ## Picasso

# %%
picasso_style = StyleTransfer(style_path = 'data/styles/picasso-self-portrait.jpg')

# %%
picasso_style.plot_style()

# %%
picasso_style.compile()

# %%
picasso_style.fit(imagenet,
                  batch_size = 8,
                  epochs = 2,
                  learning_rate = 1e-3)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
picasso_style.fit(imagenet,
                  batch_size = 8,
                  epochs = 1,
                  learning_rate = 1e-4)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
picasso_style.m_style.save_weights('results/picasso-self-portrait.h5')

# %%
picasso_style.get_top()

# %%
picasso_style.top_model.save_weights('results/picasso-self-portrait-top.h5')

# %%
picasso_akll_big = picasso_style.predict('test/akll-color-big.jpg')

# %%
picasso_akll_big = picasso_style.predict('test/akll-bw-big.jpg')

# %%
picasso_akll_big = picasso_style.predict('test/akll-color-big.jpg')

# %% [markdown]
# ## Les Miserables

# %%
les_mis_style = StyleTransfer(style_path = 'data/styles/les-mis.jpg')

# %%
les_mis_style.plot_style()

# %%
les_mis_style.compile()

# %%
les_mis_style.fit(imagenet,
                  batch_size = 8,
                  epochs = 2,
                  learning_rate = 1e-3)

# %%
les_mis_style.fit(imagenet,
                  batch_size = 8,
                  epochs = 1,
                  learning_rate = 1e-4)

# %%
les_mis_style.m_style.save_weights('results/les-mis.h5')

# %%
les_mis_style.get_top()

# %%
les_mis_style.top_model.save_weights('results/les-mis-top.h5')

# %%
les_mis_style_akll_big = les_mis_style.predict('test/akll-bw-big.jpg')

# %%
les_mis_style_akll_big = les_mis_style.predict('test/akll-color-big.jpg')

# %% [markdown]
# ## Mona Lisa

# %%
mona_lisa_style = StyleTransfer(style_path = 'data/styles/mona-lisa.jpg')

# %%
mona_lisa_style.plot_style()

# %%
mona_lisa_style.compile()

# %%
mona_lisa_style.fit(imagenet,
                    batch_size = 8,
                    epochs = 2,
                    learning_rate = 1e-3)

# %%
mona_lisa_style.fit(imagenet,
                    batch_size = 8,
                    epochs = 2,
                    learning_rate = 1e-4)

# %%
mona_lisa_style.m_style.save_weights('results/mona-lisa.h5')

# %%
mona_lisa_style.get_top()
mona_lisa_style.top_model.save_weights('results/mona-lisa-top.h5')

# %%
mona_lisa_style_akll_big = mona_lisa_style.predict('test/akll-bw-big.jpg')

# %%
mona_lisa_style_akll_big = mona_lisa_style.predict('test/akll-color-big.jpg')
